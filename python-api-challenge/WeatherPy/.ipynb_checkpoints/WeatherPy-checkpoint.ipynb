# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
#pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 621

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API key}"


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nikolskoye
# Processing Record 2 of Set 1 | caravelas
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | ternate
# Processing Record 5 of Set 1 | bredasdorp
# Processing Record 6 of Set 1 | pochutla
# Processing Record 7 of Set 1 | bani
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | san cristobal
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | carnarvon
# Processing Record 13 of Set 1 | saint anthony
# Processing Record 14 of Set 1 | san quintin
# Processing Record 15 of Set 1 | kodiak
# Processing Record 16 of Set 1 | bambui
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | mersing
# Processing Record 19 of Set 1 | mar del plata
# Processing Record 20 of Set 1 | bonito
# Processing Record 21 of Set 1 | miri
# Processing Record 22 of Set 1 | chililabombwe
# Processing Record 23 of Set 1 | libreville
# Processing Record 24 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 1 | padang
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | georgetown
# Processing Record 28 of Set 1 | pokhara
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | amuntai
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | faanui
# Processing Record 34 of Set 1 | gogrial
# Processing Record 35 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 1 | bichura
# Processing Record 37 of Set 1 | butaritari
# Processing Record 38 of Set 1 | urengoy
# Processing Record 39 of Set 1 | codrington
# Processing Record 40 of Set 1 | tezu
# Processing Record 41 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 1 | saint-joseph
# Processing Record 44 of Set 1 | narsaq
# Processing Record 45 of Set 1 | nanortalik
# Processing Record 46 of Set 1 | saint george
# Processing Record 47 of Set 1 | bonavista
# Processing Record 48 of Set 1 | reconquista
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | gushikawa
# Processing Record 0 of Set 2 | dikson
# Processing Record 1 of Set 2 | rocha
# Processing Record 2 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 2 | nuuk
# Processing Record 4 of Set 2 | ribeira grande
# Processing Record 5 of Set 2 | buariki
# City not found. Skipping...
# Processing Record 6 of Set 2 | saint-philippe
# Processing Record 7 of Set 2 | jurm
# Processing Record 8 of Set 2 | upernavik
# Processing Record 9 of Set 2 | east london
# Processing Record 10 of Set 2 | nioro
# Processing Record 11 of Set 2 | tuktoyaktuk
# Processing Record 12 of Set 2 | fukue
# Processing Record 13 of Set 2 | tucumcari
# Processing Record 14 of Set 2 | deputatskiy
# Processing Record 15 of Set 2 | bardiyah
# Processing Record 16 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 2 | torbay
# Processing Record 18 of Set 2 | wlodawa
# Processing Record 19 of Set 2 | bluff
# Processing Record 20 of Set 2 | cape town
# Processing Record 21 of Set 2 | cayenne
# Processing Record 22 of Set 2 | gerardmer
# Processing Record 23 of Set 2 | longyearbyen
# Processing Record 24 of Set 2 | albany
# Processing Record 25 of Set 2 | matara
# Processing Record 26 of Set 2 | turayf
# Processing Record 27 of Set 2 | silca
# Processing Record 28 of Set 2 | feleacu
# Processing Record 29 of Set 2 | do gonbadan
# Processing Record 30 of Set 2 | helong
# Processing Record 31 of Set 2 | voyvozh
# Processing Record 32 of Set 2 | puerto madryn
# Processing Record 33 of Set 2 | yongan
# Processing Record 34 of Set 2 | new norfolk
# Processing Record 35 of Set 2 | thompson
# Processing Record 36 of Set 2 | mega
# Processing Record 37 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 2 | kahului
# Processing Record 39 of Set 2 | mount gambier
# Processing Record 40 of Set 2 | tashtagol
# Processing Record 41 of Set 2 | fortuna
# Processing Record 42 of Set 2 | gurskoye
# City not found. Skipping...
# Processing Record 43 of Set 2 | ushuaia
# Processing Record 44 of Set 2 | galiwinku
# City not found. Skipping...
# Processing Record 45 of Set 2 | urusha
# Processing Record 46 of Set 2 | luderitz
# Processing Record 47 of Set 2 | tiarei
# Processing Record 48 of Set 2 | norman wells
# Processing Record 49 of Set 2 | khandyga
# Processing Record 0 of Set 3 | half moon bay
# Processing Record 1 of Set 3 | hermanus
# Processing Record 2 of Set 3 | taltal
# Processing Record 3 of Set 3 | yaizu
# Processing Record 4 of Set 3 | chokurdakh
# Processing Record 5 of Set 3 | bengkulu
# Processing Record 6 of Set 3 | geraldton
# Processing Record 7 of Set 3 | beringovskiy
# Processing Record 8 of Set 3 | hilo
# Processing Record 9 of Set 3 | nemuro
# Processing Record 10 of Set 3 | marshalltown
# Processing Record 11 of Set 3 | noumea
# Processing Record 12 of Set 3 | arraial do cabo
# Processing Record 13 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 3 | cazaje
# City not found. Skipping...
# Processing Record 15 of Set 3 | westport
# Processing Record 16 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 3 | avarua
# Processing Record 18 of Set 3 | severo-kurilsk
# Processing Record 19 of Set 3 | castro
# Processing Record 20 of Set 3 | mahon
# Processing Record 21 of Set 3 | talnakh
# Processing Record 22 of Set 3 | yulara
# Processing Record 23 of Set 3 | fez
# Processing Record 24 of Set 3 | pemba
# Processing Record 25 of Set 3 | nara
# Processing Record 26 of Set 3 | biltine
# Processing Record 27 of Set 3 | bambous virieux
# Processing Record 28 of Set 3 | jamestown
# Processing Record 29 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 3 | charters towers
# Processing Record 31 of Set 3 | manta
# Processing Record 32 of Set 3 | lenger
# Processing Record 33 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 3 | los llanos de aridane
# Processing Record 36 of Set 3 | juneau
# Processing Record 37 of Set 3 | sfantu gheorghe
# Processing Record 38 of Set 3 | tiksi
# Processing Record 39 of Set 3 | pisco
# Processing Record 40 of Set 3 | turukhansk
# Processing Record 41 of Set 3 | namatanai
# Processing Record 42 of Set 3 | yuksekova
# Processing Record 43 of Set 3 | saldanha
# Processing Record 44 of Set 3 | havelock
# Processing Record 45 of Set 3 | kerki
# City not found. Skipping...
# Processing Record 46 of Set 3 | gat
# Processing Record 47 of Set 3 | matagami
# Processing Record 48 of Set 3 | hovd
# Processing Record 49 of Set 3 | komsomolskiy
# Processing Record 0 of Set 4 | hobart
# Processing Record 1 of Set 4 | brahmapuri
# City not found. Skipping...
# Processing Record 2 of Set 4 | dingle
# Processing Record 3 of Set 4 | taoudenni
# Processing Record 4 of Set 4 | yumen
# Processing Record 5 of Set 4 | emerald
# Processing Record 6 of Set 4 | saskylakh
# Processing Record 7 of Set 4 | kirovsk
# Processing Record 8 of Set 4 | salinas
# Processing Record 9 of Set 4 | airai
# Processing Record 10 of Set 4 | beloha
# Processing Record 11 of Set 4 | veraval
# Processing Record 12 of Set 4 | atar
# Processing Record 13 of Set 4 | sembe
# Processing Record 14 of Set 4 | eureka
# Processing Record 15 of Set 4 | hofn
# Processing Record 16 of Set 4 | kavieng
# Processing Record 17 of Set 4 | a
# City not found. Skipping...
# Processing Record 18 of Set 4 | tasiilaq
# Processing Record 19 of Set 4 | provideniya
# Processing Record 20 of Set 4 | vila velha
# Processing Record 21 of Set 4 | itamaraca
# Processing Record 22 of Set 4 | sola
# Processing Record 23 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 24 of Set 4 | maine-soroa
# Processing Record 25 of Set 4 | qasigiannguit
# Processing Record 26 of Set 4 | sambava
# Processing Record 27 of Set 4 | ampanihy
# Processing Record 28 of Set 4 | najran
# Processing Record 29 of Set 4 | chardara
# Processing Record 30 of Set 4 | ashcroft
# Processing Record 31 of Set 4 | bathsheba
# Processing Record 32 of Set 4 | zilupe
# Processing Record 33 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 34 of Set 4 | suntar
# Processing Record 35 of Set 4 | college
# Processing Record 36 of Set 4 | namibe
# Processing Record 37 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 4 | devonport
# Processing Record 39 of Set 4 | acapulco
# Processing Record 40 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 4 | sedelnikovo
# City not found. Skipping...
# Processing Record 42 of Set 4 | mumford
# Processing Record 43 of Set 4 | henties bay
# Processing Record 44 of Set 4 | lyuban
# Processing Record 45 of Set 4 | broome
# Processing Record 46 of Set 4 | panaba
# Processing Record 47 of Set 4 | teahupoo
# Processing Record 48 of Set 4 | lazaro cardenas
# Processing Record 49 of Set 4 | rancho palos verdes
# Processing Record 0 of Set 5 | rio grande
# Processing Record 1 of Set 5 | tiszacsege
# Processing Record 2 of Set 5 | tautira
# Processing Record 3 of Set 5 | vardo
# Processing Record 4 of Set 5 | ourem
# Processing Record 5 of Set 5 | roebourne
# Processing Record 6 of Set 5 | tsaratanana
# Processing Record 7 of Set 5 | monrovia
# Processing Record 8 of Set 5 | butterworth
# Processing Record 9 of Set 5 | khatanga
# Processing Record 10 of Set 5 | cidreira
# Processing Record 11 of Set 5 | nouakchott
# Processing Record 12 of Set 5 | kruisfontein
# Processing Record 13 of Set 5 | barrow
# Processing Record 14 of Set 5 | sao felix do xingu
# Processing Record 15 of Set 5 | souillac
# Processing Record 16 of Set 5 | noyon
# Processing Record 17 of Set 5 | indramayu
# Processing Record 18 of Set 5 | lebu
# Processing Record 19 of Set 5 | lyubim
# Processing Record 20 of Set 5 | guiratinga
# Processing Record 21 of Set 5 | tilichiki
# Processing Record 22 of Set 5 | kodinsk
# Processing Record 23 of Set 5 | smidovich
# Processing Record 24 of Set 5 | harper
# Processing Record 25 of Set 5 | ponta do sol
# Processing Record 26 of Set 5 | dien bien
# City not found. Skipping...
# Processing Record 27 of Set 5 | algiers
# Processing Record 28 of Set 5 | rudbar
# Processing Record 29 of Set 5 | mokhsogollokh
# Processing Record 30 of Set 5 | comodoro rivadavia
# Processing Record 31 of Set 5 | novaya lyalya
# Processing Record 32 of Set 5 | shimoda
# Processing Record 33 of Set 5 | tuatapere
# Processing Record 34 of Set 5 | dordrecht
# Processing Record 35 of Set 5 | port elizabeth
# Processing Record 36 of Set 5 | kumasi
# Processing Record 37 of Set 5 | iqaluit
# Processing Record 38 of Set 5 | iracoubo
# Processing Record 39 of Set 5 | marienburg
# Processing Record 40 of Set 5 | ancud
# Processing Record 41 of Set 5 | mareeba
# Processing Record 42 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 5 | gulf gate estates
# Processing Record 44 of Set 5 | gornozavodsk
# Processing Record 45 of Set 5 | emba
# Processing Record 46 of Set 5 | mount isa
# Processing Record 47 of Set 5 | quatre cocos
# Processing Record 48 of Set 5 | matamoros
# Processing Record 49 of Set 5 | guarapari
# Processing Record 0 of Set 6 | sioux lookout
# Processing Record 1 of Set 6 | fort frances
# Processing Record 2 of Set 6 | vila franca do campo
# Processing Record 3 of Set 6 | mercedes
# Processing Record 4 of Set 6 | shirokiy
# Processing Record 5 of Set 6 | port alfred
# Processing Record 6 of Set 6 | christchurch
# Processing Record 7 of Set 6 | axim
# Processing Record 8 of Set 6 | victoria
# Processing Record 9 of Set 6 | zambezi
# Processing Record 10 of Set 6 | mandapam
# Processing Record 11 of Set 6 | makat
# Processing Record 12 of Set 6 | celestun
# Processing Record 13 of Set 6 | katherine
# Processing Record 14 of Set 6 | hobyo
# Processing Record 15 of Set 6 | mahebourg
# Processing Record 16 of Set 6 | ormara
# Processing Record 17 of Set 6 | llata
# Processing Record 18 of Set 6 | ichtegem
# Processing Record 19 of Set 6 | pangnirtung
# Processing Record 20 of Set 6 | loveland
# Processing Record 21 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 6 | qaanaaq
# Processing Record 23 of Set 6 | skelleftea
# Processing Record 24 of Set 6 | coquimbo
# Processing Record 25 of Set 6 | jiuquan
# Processing Record 26 of Set 6 | mirnyy
# Processing Record 27 of Set 6 | kuala sungai baru
# Processing Record 28 of Set 6 | hithadhoo
# Processing Record 29 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 30 of Set 6 | the valley
# Processing Record 31 of Set 6 | kiama
# Processing Record 32 of Set 6 | esperance
# Processing Record 33 of Set 6 | la ronge
# Processing Record 34 of Set 6 | adrar
# Processing Record 35 of Set 6 | yertsevo
# Processing Record 36 of Set 6 | sibolga
# Processing Record 37 of Set 6 | yazman
# Processing Record 38 of Set 6 | bayanday
# Processing Record 39 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 40 of Set 6 | kaitangata
# Processing Record 41 of Set 6 | baculin
# Processing Record 42 of Set 6 | soe
# Processing Record 43 of Set 6 | batagay-alyta
# Processing Record 44 of Set 6 | sitka
# Processing Record 45 of Set 6 | port blair
# Processing Record 46 of Set 6 | darab
# Processing Record 47 of Set 6 | kristinehamn
# Processing Record 48 of Set 6 | kudahuvadhoo
# Processing Record 49 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 0 of Set 7 | itoman
# Processing Record 1 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 7 | moose factory
# Processing Record 3 of Set 7 | zaraza
# Processing Record 4 of Set 7 | kungurtug
# Processing Record 5 of Set 7 | ust-uda
# Processing Record 6 of Set 7 | maanshan
# Processing Record 7 of Set 7 | hamilton
# Processing Record 8 of Set 7 | port-gentil
# Processing Record 9 of Set 7 | karasjok
# Processing Record 10 of Set 7 | platteville
# Processing Record 11 of Set 7 | port macquarie
# Processing Record 12 of Set 7 | sol-iletsk
# Processing Record 13 of Set 7 | cabo san lucas
# Processing Record 14 of Set 7 | ha giang
# Processing Record 15 of Set 7 | ketchikan
# Processing Record 16 of Set 7 | sinnamary
# Processing Record 17 of Set 7 | kismayo
# Processing Record 18 of Set 7 | cuitareo
# Processing Record 19 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 7 | nizhniy kuranakh
# Processing Record 21 of Set 7 | sandakan
# Processing Record 22 of Set 7 | xiamen
# Processing Record 23 of Set 7 | tateyama
# Processing Record 24 of Set 7 | uroteppa
# City not found. Skipping...
# Processing Record 25 of Set 7 | constitucion
# Processing Record 26 of Set 7 | gualaquiza
# Processing Record 27 of Set 7 | marshfield
# Processing Record 28 of Set 7 | boralday
# Processing Record 29 of Set 7 | tumbagaan
# Processing Record 30 of Set 7 | osijek
# Processing Record 31 of Set 7 | sur
# Processing Record 32 of Set 7 | bairnsdale
# Processing Record 33 of Set 7 | rantepao
# Processing Record 34 of Set 7 | san juan
# Processing Record 35 of Set 7 | moron
# Processing Record 36 of Set 7 | avera
# Processing Record 37 of Set 7 | chulucanas
# Processing Record 38 of Set 7 | fort nelson
# Processing Record 39 of Set 7 | luanda
# Processing Record 40 of Set 7 | kieta
# Processing Record 41 of Set 7 | nanchang
# Processing Record 42 of Set 7 | chuy
# Processing Record 43 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 7 | angoche
# Processing Record 45 of Set 7 | turbat
# Processing Record 46 of Set 7 | bonfim
# Processing Record 47 of Set 7 | umm kaddadah
# Processing Record 48 of Set 7 | ust-kan
# Processing Record 49 of Set 7 | orocue
# Processing Record 0 of Set 8 | mahanoro
# Processing Record 1 of Set 8 | etchojoa
# Processing Record 2 of Set 8 | maniitsoq
# Processing Record 3 of Set 8 | izacic
# Processing Record 4 of Set 8 | chara
# Processing Record 5 of Set 8 | djambala
# Processing Record 6 of Set 8 | port hardy
# Processing Record 7 of Set 8 | katsuura
# Processing Record 8 of Set 8 | ruwi
# Processing Record 9 of Set 8 | rio gallegos
# Processing Record 10 of Set 8 | kwinana
# Processing Record 11 of Set 8 | ludvika
# Processing Record 12 of Set 8 | yialos
# City not found. Skipping...
# Processing Record 13 of Set 8 | vao
# Processing Record 14 of Set 8 | rantauprapat
# Processing Record 15 of Set 8 | kushima
# Processing Record 16 of Set 8 | bayonet point
# Processing Record 17 of Set 8 | yaan
# Processing Record 18 of Set 8 | cabimas
# Processing Record 19 of Set 8 | asau
# Processing Record 20 of Set 8 | ozinki
# Processing Record 21 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 22 of Set 8 | baruun-urt
# Processing Record 23 of Set 8 | samarai
# Processing Record 24 of Set 8 | zhangjiakou
# Processing Record 25 of Set 8 | santa cruz
# Processing Record 26 of Set 8 | monte azul
# Processing Record 27 of Set 8 | camargo
# Processing Record 28 of Set 8 | warrington
# Processing Record 29 of Set 8 | katangli
# Processing Record 30 of Set 8 | morondava
# Processing Record 31 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 32 of Set 8 | berlevag
# Processing Record 33 of Set 8 | oksfjord
# Processing Record 34 of Set 8 | lompoc
# Processing Record 35 of Set 8 | pucallpa
# Processing Record 36 of Set 8 | demyansk
# Processing Record 37 of Set 8 | tandalti
# Processing Record 38 of Set 8 | mesyagutovo
# Processing Record 39 of Set 8 | makhalino
# Processing Record 40 of Set 8 | dabeiba
# Processing Record 41 of Set 8 | kyshtovka
# Processing Record 42 of Set 8 | visby
# Processing Record 43 of Set 8 | husavik
# Processing Record 44 of Set 8 | kirakira
# Processing Record 45 of Set 8 | dombarovskiy
# Processing Record 46 of Set 8 | portoferraio
# Processing Record 47 of Set 8 | bojnurd
# Processing Record 48 of Set 8 | bereda
# Processing Record 49 of Set 8 | alta floresta
# Processing Record 0 of Set 9 | gigmoto
# Processing Record 1 of Set 9 | guerrero negro
# Processing Record 2 of Set 9 | lagoa
# Processing Record 3 of Set 9 | abu dhabi
# Processing Record 4 of Set 9 | shetpe
# Processing Record 5 of Set 9 | astara
# Processing Record 6 of Set 9 | kibre mengist
# Processing Record 7 of Set 9 | xinmin
# Processing Record 8 of Set 9 | filingue
# Processing Record 9 of Set 9 | zakamensk
# Processing Record 10 of Set 9 | karratha
# Processing Record 11 of Set 9 | iquique
# Processing Record 12 of Set 9 | san policarpo
# Processing Record 13 of Set 9 | coffs harbour
# Processing Record 14 of Set 9 | pevek
# Processing Record 15 of Set 9 | barcelos
# Processing Record 16 of Set 9 | saint-georges
# Processing Record 17 of Set 9 | bercel
# Processing Record 18 of Set 9 | fairbanks
# Processing Record 19 of Set 9 | tabuk
# Processing Record 20 of Set 9 | haimen
# Processing Record 21 of Set 9 | necochea
# Processing Record 22 of Set 9 | dwarka
# Processing Record 23 of Set 9 | mtambile
# Processing Record 24 of Set 9 | leningradskiy
# Processing Record 25 of Set 9 | eldikan
# City not found. Skipping...
# Processing Record 26 of Set 9 | sao filipe
# Processing Record 27 of Set 9 | teguise
# Processing Record 28 of Set 9 | nyandoma
# Processing Record 29 of Set 9 | pedasi
# Processing Record 30 of Set 9 | champerico
# Processing Record 31 of Set 9 | omboue
# Processing Record 32 of Set 9 | presidencia roque saenz pena
# Processing Record 33 of Set 9 | burnie
# Processing Record 34 of Set 9 | buala
# Processing Record 35 of Set 9 | tiznit
# Processing Record 36 of Set 9 | bambanglipuro
# Processing Record 37 of Set 9 | kenai
# Processing Record 38 of Set 9 | khakurinokhabl
# Processing Record 39 of Set 9 | gazli
# Processing Record 40 of Set 9 | willowmore
# Processing Record 41 of Set 9 | jardim
# Processing Record 42 of Set 9 | abu zabad
# Processing Record 43 of Set 9 | cheremkhovo
# Processing Record 44 of Set 9 | okhotsk
# Processing Record 45 of Set 9 | te anau
# Processing Record 46 of Set 9 | nizwa
# Processing Record 47 of Set 9 | touros
# Processing Record 48 of Set 9 | lorengau
# Processing Record 49 of Set 9 | lubango
# Processing Record 0 of Set 10 | ziarat
# Processing Record 1 of Set 10 | walvis bay
# Processing Record 2 of Set 10 | ugoofaaru
# Processing Record 3 of Set 10 | lasa
# Processing Record 4 of Set 10 | roberval
# Processing Record 5 of Set 10 | bajo baudo
# City not found. Skipping...
# Processing Record 6 of Set 10 | manacapuru
# Processing Record 7 of Set 10 | aba
# Processing Record 8 of Set 10 | hasaki
# Processing Record 9 of Set 10 | iskateley
# Processing Record 10 of Set 10 | pangai
# Processing Record 11 of Set 10 | guanare
# Processing Record 12 of Set 10 | churapcha
# Processing Record 13 of Set 10 | huarmey
# Processing Record 14 of Set 10 | qaqortoq
# Processing Record 15 of Set 10 | karakendzha
# City not found. Skipping...
# Processing Record 16 of Set 10 | nizhnevartovsk
# Processing Record 17 of Set 10 | kupang
# Processing Record 18 of Set 10 | luwuk
# Processing Record 19 of Set 10 | itarema
# Processing Record 20 of Set 10 | mehamn
# Processing Record 21 of Set 10 | prikubanskiy
# Processing Record 22 of Set 10 | seoni malwa
# Processing Record 23 of Set 10 | harbour breton
# Processing Record 24 of Set 10 | formosa
# Processing Record 25 of Set 10 | dawei
# Processing Record 26 of Set 10 | cockburn town
# Processing Record 27 of Set 10 | hami
# Processing Record 28 of Set 10 | vallenar
# Processing Record 29 of Set 10 | xiaoweizhai
# Processing Record 30 of Set 10 | port moresby
# Processing Record 31 of Set 10 | mogadishu
# Processing Record 32 of Set 10 | araouane
# Processing Record 33 of Set 10 | golpayegan
# Processing Record 34 of Set 10 | manggar
# Processing Record 35 of Set 10 | misratah
# Processing Record 36 of Set 10 | igarka
# Processing Record 37 of Set 10 | ipojuca
# Processing Record 38 of Set 10 | ocampo
# Processing Record 39 of Set 10 | chapais
# Processing Record 40 of Set 10 | mitu
# Processing Record 41 of Set 10 | linhares
# Processing Record 42 of Set 10 | ankang
# Processing Record 43 of Set 10 | macusani
# Processing Record 44 of Set 10 | irati
# Processing Record 45 of Set 10 | pasni
# Processing Record 46 of Set 10 | valdivia
# Processing Record 47 of Set 10 | pospelikha
# Processing Record 48 of Set 10 | inirida
# Processing Record 49 of Set 10 | fort morgan
# Processing Record 0 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 11 | yerbogachen
# Processing Record 2 of Set 11 | kundgol
# Processing Record 3 of Set 11 | anadyr
# Processing Record 4 of Set 11 | miranda
# Processing Record 5 of Set 11 | ahipara
# Processing Record 6 of Set 11 | valley city
# Processing Record 7 of Set 11 | dawlatabad
# Processing Record 8 of Set 11 | tete
# Processing Record 9 of Set 11 | americus
# Processing Record 10 of Set 11 | homer
# Processing Record 11 of Set 11 | ginir
# Processing Record 12 of Set 11 | belmonte
# Processing Record 13 of Set 11 | tahta
# Processing Record 14 of Set 11 | west point
# Processing Record 15 of Set 11 | miraflores
# Processing Record 16 of Set 11 | cherskiy
# Processing Record 17 of Set 11 | grand-santi
# Processing Record 18 of Set 11 | bilibino
# Processing Record 19 of Set 11 | cururupu
# Processing Record 20 of Set 11 | taybad
# Processing Record 21 of Set 11 | kaduqli
# Processing Record 22 of Set 11 | baft
# Processing Record 23 of Set 11 | springdale
# Processing Record 24 of Set 11 | bilma
# Processing Record 25 of Set 11 | mantua
# Processing Record 26 of Set 11 | haines junction
# Processing Record 27 of Set 11 | sivas
# Processing Record 28 of Set 11 | gornopravdinsk
# Processing Record 29 of Set 11 | cape coast
# Processing Record 30 of Set 11 | amazar
# Processing Record 31 of Set 11 | bismarck
# Processing Record 32 of Set 11 | ville-marie
# Processing Record 33 of Set 11 | port lincoln
# Processing Record 34 of Set 11 | orotukan
# Processing Record 35 of Set 11 | coihaique
# Processing Record 36 of Set 11 | atasu
# Processing Record 37 of Set 11 | kavaratti
# Processing Record 38 of Set 11 | murgab
# Processing Record 39 of Set 11 | punakha
# Processing Record 40 of Set 11 | zatoka
# Processing Record 41 of Set 11 | pimentel
# Processing Record 42 of Set 11 | novo aripuana
# Processing Record 43 of Set 11 | santa cruz cabralia
# Processing Record 44 of Set 11 | liwale
# Processing Record 45 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 11 | kambove
# Processing Record 47 of Set 11 | opuwo
# Processing Record 48 of Set 11 | chase
# Processing Record 49 of Set 11 | grindavik
# Processing Record 0 of Set 12 | sinjar
# Processing Record 1 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 2 of Set 12 | ribas do rio pardo
# Processing Record 3 of Set 12 | ilulissat
# Processing Record 4 of Set 12 | hualmay
# Processing Record 5 of Set 12 | nelson bay
# Processing Record 6 of Set 12 | sibsagar
# Processing Record 7 of Set 12 | havoysund
# Processing Record 8 of Set 12 | margate
# Processing Record 9 of Set 12 | jalu
# Processing Record 10 of Set 12 | tuy hoa
# Processing Record 11 of Set 12 | calbuco
# Processing Record 12 of Set 12 | tamasane
# Processing Record 13 of Set 12 | colares
# Processing Record 14 of Set 12 | taylorville
# Processing Record 15 of Set 12 | calderitas
# Processing Record 16 of Set 12 | katha
# City not found. Skipping...
# Processing Record 17 of Set 12 | machiques
# Processing Record 18 of Set 12 | woodward
# Processing Record 19 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 12 | gandai
# Processing Record 21 of Set 12 | roald
# Processing Record 22 of Set 12 | laguna
# Processing Record 23 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 12 | cap malheureux
# Processing Record 25 of Set 12 | mandal
# Processing Record 26 of Set 12 | bogande
# Processing Record 27 of Set 12 | coahuayana
# Processing Record 28 of Set 12 | andalan
# Processing Record 29 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 30 of Set 12 | bima
# Processing Record 31 of Set 12 | aklavik
# Processing Record 32 of Set 12 | tarko-sale
# Processing Record 33 of Set 12 | faya
# Processing Record 34 of Set 12 | zhigansk
# Processing Record 35 of Set 12 | erzin
# Processing Record 36 of Set 12 | paulo ramos
# Processing Record 37 of Set 12 | severobaykalsk
# Processing Record 38 of Set 12 | chambas
# Processing Record 39 of Set 12 | meulaboh
# Processing Record 40 of Set 12 | hov
# Processing Record 41 of Set 12 | kefamenanu
# Processing Record 42 of Set 12 | agua verde
# Processing Record 43 of Set 12 | bubaque
# Processing Record 44 of Set 12 | isangel
# Processing Record 45 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 12 | carutapera
# Processing Record 47 of Set 12 | lyaskelya
# Processing Record 48 of Set 12 | sayyan
# Processing Record 49 of Set 12 | lata
# Processing Record 0 of Set 13 | mildura
# Processing Record 1 of Set 13 | sovetskiy
# Processing Record 2 of Set 13 | sunndalsora
# Processing Record 3 of Set 13 | pundaguitan
# Processing Record 4 of Set 13 | markala
# Processing Record 5 of Set 13 | os
# City not found. Skipping...
# Processing Record 6 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 7 of Set 13 | yablonovo
# Processing Record 8 of Set 13 | kendari
# Processing Record 9 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 10 of Set 13 | gorele
# Processing Record 11 of Set 13 | zyryanovsk
# Processing Record 12 of Set 13 | nantucket
# Processing Record 13 of Set 13 | bonthe
# Processing Record 14 of Set 13 | stockbridge
# Processing Record 15 of Set 13 | kuching
# Processing Record 16 of Set 13 | arlit
# Processing Record 17 of Set 13 | paamiut
# Processing Record 18 of Set 13 | saiha
# Processing Record 19 of Set 13 | lat yao
# Processing Record 20 of Set 13 | lavrentiya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          571
# Lat           571
# Lng           571
# Max Temp      571
# Humidity      571
# Cloudiness    571
# Wind Speed    571
# Country       571
# Date          571
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   nikolskoye  59.7035   30.7861     14.33        54          66        4.45
# 1    caravelas -17.7125  -39.2481     21.71        93           6        1.06
# 2  yellowknife  62.4560 -114.3525      9.29        93         100        6.71
# 3      ternate   0.8000  127.4000     29.08        76          27        4.77
# 4   bredasdorp -34.5322   20.0403     10.40        90          32        0.97
#
#   Country        Date
# 0      RU  1684213357
# 1      BR  1684213349
# 2      CA  1684213249
# 3      ID  1684213639
# 4      ZA  1684213296

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         nikolskoye  59.7035   30.7861     14.33        54          66
# 1          caravelas -17.7125  -39.2481     21.71        93           6
# 2        yellowknife  62.4560 -114.3525      9.29        93         100
# 3            ternate   0.8000  127.4000     29.08        76          27
# 4         bredasdorp -34.5322   20.0403     10.40        90          32
#
#          Wind Speed Country        Date
# City_ID
# 0              4.45      RU  1684213357
# 1              1.06      BR  1684213349
# 2              6.71      CA  1684213249
# 3              4.77      ID  1684213639
# 4              0.97      ZA  1684213296

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"])

# Incorporate the other graph properties
plt.title("Latitude Vs. Temperature")
plt.xlabel("Temperature")
plt.ylabel("Latitude")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"])

# Incorporate the other graph properties
plt.title("Latitude Vs. Humidity")
plt.xlabel("Humidity")
plt.ylabel("Latitude")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"])

# Incorporate the other graph properties
plt.title("Latitude Vs. Cloudiness")
plt.xlabel("Cloudiness")
plt.ylabel("Latitude")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"])

# Incorporate the other graph properties
plt.title("Latitude Vs. Wind Speed Plot")
plt.xlabel("Wind Speed Plot")
plt.ylabel("Latitude")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def Linear_Regression_plots(x_values,y_values,title,text_coordinates):
    
    # Run regression on Southern Hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))
    
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,(20,15),fontsize=15,color="red")
    plt.xlabel("Latitude")
    plt.ylabel("Title")
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         nikolskoye  59.7035   30.7861     14.33        54          66
# 2        yellowknife  62.4560 -114.3525      9.29        93         100
# 3            ternate   0.8000  127.4000     29.08        76          27
# 5           pochutla  15.7432  -96.4661     25.46        69          24
# 6               bani  18.2833  -70.3333     24.36        85          69
#
#          Wind Speed Country        Date
# City_ID
# 0              4.45      RU  1684213357
# 2              6.71      CA  1684213249
# 3              4.77      ID  1684213639
# 5              0.91      MX  1684213393
# 6              2.19      DO  1684213640

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1         caravelas -17.7125  -39.2481     21.71        93           6
# 4        bredasdorp -34.5322   20.0403     10.40        90          32
# 8             vaini -21.2000 -175.2000     22.09        88         100
# 10          rikitea -23.1203 -134.9692     23.93        71           6
# 11        carnarvon -24.8667  113.6333     24.27        32           0
#
#          Wind Speed Country        Date
# City_ID
# 1              1.06      BR  1684213349
# 4              0.97      ZA  1684213296
# 8              5.14      TO  1684213332
# 10             1.76      PF  1684213295
# 11             2.16      AU  1684213360

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
Linear_Regression_plots(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"], 'Max Temp', 'text_coordinates')
# Out:
# The r-squared is: -0.818932758337212

# %%
# Linear regression on Southern Hemisphere
Linear_Regression_plots(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"], 'Max Temp', 'text_coordinates')
# Out:
# The r-squared is: 0.7153377943921191

# %% [markdown]
# **Discussion about the linear relationship:** The Northern Hemisphere plot shows that there is a downward slope which could mean there is a strong correlation in Temperature vs Latitude.
#
# The Southern Hemisphere plot shows that there is upward slope which could mean a strong correlation in Temperature vs Latitude.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
Linear_Regression_plots(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], 'Latitude', 'Humidity')
# Out:
# The r-squared is: 0.007036899423016182

# %%
# Southern Hemisphere
Linear_Regression_plots(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], 'Latitude', 'Humidity')
# Out:
# The r-squared is: 0.1503258805233987

# %% [markdown]
# **Discussion about the linear relationship:** The Northern Hemisphere plot shows that there is no correlation in Humidity due to the fact that the slope is almost horizontal.
#
# The Southern Hemisphere plot shows that there is no correlation in Humidity due to the fact that the slope has a slight upward slope.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
Linear_Regression_plots(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], 'Latitude', 'Cloudiness')
# Out:
# The r-squared is: 0.051488704109054366

# %%
# Southern Hemisphere
Linear_Regression_plots(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], 'Latitude', 'Cloudiness')
# Out:
# The r-squared is: 0.2645435377836759

# %% [markdown]
# **Discussion about the linear relationship:** The Northern Hemisphere plot shows there is very little correlation in cloudiness due to the fact that the slope is basically horizontal.
#
# The Southern Hemisphere plot shows there is an upwards correlation in cloudiness. In comparison it seems there is more of a difference between Northern and Southern Hemisphere when it comes to cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
Linear_Regression_plots(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], 'Latitude', 'Wind Speed')
# Out:
# The r-squared is: 0.13828777905985154

# %%
# Southern Hemisphere
Linear_Regression_plots(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], 'Latitude', 'Wind Speed')
# Out:
# The r-squared is: -0.1660542828955128

# %% [markdown]
# **Discussion about the linear relationship:** The Northern Hemisphere plot shows there is pratically no correlation in Wind Speed with a slope that is horizontal.
#
# The Southern Hemisphere plot shows a correlation in Wind Speed with a minimal downward slope.
